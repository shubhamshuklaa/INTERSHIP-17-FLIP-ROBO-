# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv')

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# No Null Value Found

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.var()
# Out:
# Length             0.014422
# Diameter           0.009849
# Height             0.001750
# Whole weight       0.240481
# Shucked weight     0.049268
# Viscera weight     0.012015
# Shell weight       0.019377
# Rings             10.395266
# dtype: float64

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# float ,object and int datatype is present ,object data type have to convert into int/float value

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(10,5))
plt.title("Target Columns")
sns.countplot(df['Sex'])
# Out:
# <AxesSubplot:title={'center':'Target Columns'}, xlabel='Sex', ylabel='count'>

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
for i in df:
    plt.figure(figsize=(10,3))
    sns.histplot(df[i],kde=True)
    plt.show()

# %%
sns.kdeplot(df['Diameter'])
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %%
sns.kdeplot(df['Shell weight'])
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Density'>

# %%
sns.kdeplot(df['Height'])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
sns.kdeplot(df['Whole weight'])
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Density'>

# %%
sns.kdeplot(df['Length'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# NO NULL VALUE FOUND

# %%
plt.figure(figsize=(22,8))
sn = sns.countplot(x='Length',data=df, hue='Sex', palette=['pink','crimson',"Yellow"])

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='Sex',y='Length',data=df)
plt.show()

# %% [markdown]
# LENGTH OF FEMALE IS MORE

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='Sex',y='Diameter',data=df)
plt.show()

# %% [markdown]
# DIAMETER OF FEMALE IS MORE THAN MALE & INFANT

# %%
plt.figure(figsize=(10,3))
sns.barplot(x='Sex',y='Height',data=df)
plt.show()

# %%
plt.figure(figsize=(10,3))
sns.barplot(x='Sex',y='Whole weight',data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,3))
sns.barplot(x='Sex',y='Shell weight',data=df)
plt.show()

# %%
plt.figure(figsize=(10,3))
sns.barplot(x='Sex',y='Shucked weight',data=df)
plt.show()

# %%
plt.figure(figsize=(10,3))
sns.barplot(x='Sex',y='Viscera weight',data=df)
plt.show()

# %%
plt.figure(figsize=(10,3))
sns.barplot(x='Sex',y='Rings',data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
plt.title('Comparision between Length and Diameter')
sns.scatterplot(df['Length'],df['Diameter'],hue=df['Sex'])
plt.show()

# %%
plt.title('Comparision Between Length and Height')
sns.scatterplot(df['Length'],df['Height'],hue=df['Sex'])
plt.show()

# %%
plt.title('Comparision Between Shell weight and Rings')
sns.scatterplot(df['Shell weight'],df['Rings'],hue=df['Sex'])
plt.show()

# %%
plt.title('Comparision Between Diameter and Height')
sns.scatterplot(df['Diameter'],df['Height'],hue=df['Sex'])
plt.show()

# %%
plt.title('Comparision Between Whole weight and Shucked weight')
sns.scatterplot(df['Whole weight'],df['Shucked weight'],hue=df['Sex'])
plt.show()

# %%
sns.countplot(df['Sex'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.pairplot(df,hue='Sex')

# %%
cor=df.corr()

# %%
cor
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %%
sns.heatmap(cor,annot=True)
# Out:
# <AxesSubplot:>

# %%
df['Sex'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()

# %%
df['Sex']=LE.fit_transform(df['Sex'])

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
for i in df:
    sns.boxplot(df[i])
    plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC

# %%
x=df.drop(['Sex'],axis=1)

# %%
y=df['Sex']

# %%
from sklearn.tree import DecisionTreeClassifier
maxAcc=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=i)
    DT=DecisionTreeClassifier()
    DT.fit(x_train,y_train)
    pred=DT.predict(x_test)
    accu=accuracy_score(y_test,pred)
    if accu>maxAcc:
        maxAcc=accu
        maxRs=1
print("Best accuracy -",maxAcc,'Best Random state = ',maxRs)
# Out:
# Best accuracy - 0.5250181290790428 Best Random state =  1

# %%
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.33, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit_transform(x_train)
# Out:
# array([[-0.97798043, -1.02817754, -0.87556546, ..., -1.00078942,
#         -0.81250258,  0.02187934],
#        [-0.02850463, -0.12714687,  1.05161528, ..., -0.64034347,
#          0.03799449,  3.69498368],
#        [ 0.42559249,  0.2733112 ,  0.4092217 , ...,  0.47749525,
#         -0.06831764, -0.28421268],
#        ...,
#        [-1.67976689, -1.6789219 , -1.26100161, ..., -1.40229884,
#         -1.39721932, -1.50858079],
#        [ 0.01277692,  0.02302491, -0.61860803, ..., -0.15670712,
#         -0.42269142, -0.89639674],
#        [-1.88617467, -1.82909368, -1.51795904, ..., -1.35211016,
#         -1.41493801, -0.28421268]])

# %%
x.skew()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %%
DTC=DecisionTreeClassifier()
DTC.fit(x_train,y_train)
pred=DTC.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)
confusion_matrix = confusion_matrix(y_test,pred)
print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
print('confusion Matrix :', confusion_matrix)
# Out:
# Accuracy Score : 0.48223350253807107
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.40      0.39      0.40       431
#            1       0.61      0.61      0.61       434
#            2       0.44      0.45      0.45       514
#
#     accuracy                           0.48      1379
#    macro avg       0.48      0.48      0.48      1379
# weighted avg       0.48      0.48      0.48      1379
#
# confusion Matrix : [[170  73 188]
#  [ 64 263 107]
#  [187  95 232]]

# %%
RF=RandomForestClassifier(max_depth=2, random_state=0)
RF.fit(x_train,y_train)
pred=RF.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 0.546047860768673
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       431
#            1       0.63      0.83      0.72       434
#            2       0.48      0.77      0.59       514
#
#     accuracy                           0.55      1379
#    macro avg       0.37      0.53      0.44      1379
# weighted avg       0.38      0.55      0.45      1379

# %%
AD=AdaBoostClassifier(n_estimators=100)
AD.fit(x_train,y_train)
pred=AD.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 0.5315445975344453
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.44      0.35      0.39       431
#            1       0.67      0.80      0.73       434
#            2       0.46      0.46      0.46       514
#
#     accuracy                           0.53      1379
#    macro avg       0.52      0.54      0.52      1379
# weighted avg       0.52      0.53      0.52      1379

# %%
SV=SVC()
SV.fit(x_train,y_train)
pred=SV.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 0.5503988397389412
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       431
#            1       0.69      0.79      0.74       434
#            2       0.47      0.81      0.60       514
#
#     accuracy                           0.55      1379
#    macro avg       0.39      0.53      0.44      1379
# weighted avg       0.39      0.55      0.45      1379

# %%
LG=LogisticRegression()
LG.fit(x_train,y_train)
pred=LG.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 0.5627266134880348
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.50      0.32      0.39       431
#            1       0.66      0.83      0.74       434
#            2       0.50      0.54      0.52       514
#
#     accuracy                           0.56      1379
#    macro avg       0.55      0.56      0.55      1379
# weighted avg       0.55      0.56      0.55      1379

# %%
gnb=MultinomialNB()
gnb.fit(x_train,y_train)
pred=gnb.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 0.48005801305293694
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       431
#            1       0.56      0.61      0.58       434
#            2       0.44      0.78      0.56       514
#
#     accuracy                           0.48      1379
#    macro avg       0.33      0.46      0.38      1379
# weighted avg       0.34      0.48      0.39      1379

# %%
from sklearn.model_selection import cross_val_score

# %%
print('Decission Tree :',cross_val_score(DTC,x,y,cv=5).mean())
# Out:
# Decission Tree : 0.5025103859267113

# %%
print('Random Forest :',cross_val_score(RF,x,y,cv=5).mean())
# Out:
# Random Forest : 0.5300478468899522

# %%
print('Adaboost Tree  :',cross_val_score(AD,x,y,cv=5).mean())
# Out:
# Adaboost Tree  : 0.5240664126292869

# %%
print('Logistic Regression: ',cross_val_score(LG,x,y,cv=5).mean())
# Out:
# Logistic Regression:  0.5532722115577458

# %%
print('Support Vector :',cross_val_score(SV,x,y,cv=5).mean())
# Out:
# Support Vector : 0.5336386557029481

# %%
print('multinomailNB :',cross_val_score(gnb,x,y,cv=5).mean())
# Out:
# multinomailNB : 0.4553545540497952

# %% [markdown]
# # HYPERPERAMETER TUNNING

# %%
from sklearn.model_selection import GridSearchCV
parameter ={'max_depth':np.arange(2,10),
           'criterion':['gini', 'entropy'],
           'splitter':['best','random']}
GCV=GridSearchCV(DecisionTreeClassifier(),parameter,cv=5)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                          'splitter': ['best', 'random']})

# %%
GCV.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 4, 'splitter': 'best'}

# %%
Final_model=DecisionTreeClassifier(criterion='entropy',max_depth=4,splitter='best')
Final_model.fit(x_train,y_train)
pred=Final_model.predict(x_test)
accu=accuracy_score(y_test,pred)
print(accu*100)
# Out:
# 53.87962291515591

# %%
import joblib
joblib.dump(Final_model,'Final_model.pkl')
# Out:
# ['Final_model.pkl']
